# %% [markdown]
# # TOP 500 supercomputer mining - Challenge 1
#
# # 1-A
#
# In this challenge you will mine top500 website to retrieve information on the most powerfull supercomputer of the last years.
#
# Your task is to scrape information for the top 500 supercomputers from 2014 to 2018. The information should include:
#
# * **Rank**
#
# * **Name**
#
# * **Year**
#
# * **Description**
#
# * **Company**
#
# * **Country**
#
# * **Cores**
#
# * **RMax (TFlops/s)**
#
# * **RPeak (TFlops/s)**
#
# * **Power (kW)**
#
#
# The root url is the following:
# https://www.top500.org/
#
#
# You need to navigate the web in order to extract all information for 2500 supercomputers. As an example, the first urls are:
#
# https://www.top500.org/lists/2014/11/?page=1
#
#
# https://www.top500.org/list/2014/11/?page=2
#
#
#
# Write code that do the following:
# 1. Look for the url to scrape.
# 2. Make request.
# 3. Return HTML string.
# 4. Parse and extract all features. Create a dictionary with these fields.
# 5. Return a list of dictionaries.

# %%
# Your code here

import requests
from bs4 import BeautifulSoup
import json
import re

# %%
url = 'https://www.top500.org/list/2014/11/?page=1'
res = requests.get(url).content
soup = BeautifulSoup(res,'html.parser')
table_tr = soup.select('table > tr')
scrap_dict={}

for element in table_tr:
    scrap_dict['rank'] = element.find_all('td')[0].text
print(scrap_dict)
# Out:
# {'rank': '100'}

# %%
supercomputers = []

for year in range (2014,2019):
    for page in range (1,6):
        month = 11
        url = 'https://www.top500.org/list/{}/{}/?page={}'.format(year, month, page)
        res = requests.get(url).content
        soup = BeautifulSoup(res,'html.parser')
        table_tr = soup.select('table > tr') 
        for element in table_tr:
            dict_data = {}
            data = {'rank':element.find_all('td')[0].text,
                    'name':element.find_all('td')[2].text.split()[0],
                    'year': year,
                    'description':(element.find_all('a')[0].text) + " " + (' '.join(element.find_all('a')[1].text.split()[2:])),
                    'company':element.find_all('br')[1].text,
                    'country':str(element.find_all('td')[1]).split('br')[-1].replace('/>','').replace('</td>',''),
                    'cores': element.find_all('td')[3].text,
                    'rmax': element.find_all('td')[4].text,
                    'rpeak': element.find_all('td')[5].text,
                    'power': element.find_all('td')[6].text}
            dict_data.update(data)
            supercomputers.append(dict_data)
print(supercomputers)
# Out:
# [{'rank': '1', 'name': 'Tianhe-2A', 'year': 2014, 'description': 'National Super Computer Center in Guangzhou TH-IVB-FEP Cluster, Intel Xeon E5-2692 12C 2.200GHz, TH Express-2, Intel Xeon Phi 31S1P', 'company': 'NUDT', 'country': 'China', 'cores': '3,120,000', 'rmax': '33,862.7', 'rpeak': '54,902.4', 'power': '17,808'}, {'rank': '2', 'name': 'Titan', 'year': 2014, 'description': 'DOE/SC/Oak Ridge National Laboratory Cray XK7, Opteron 6274 16C 2.200GHz, Cray Gemini interconnect, NVIDIA K20x', 'company': 'Cray Inc.', 'country': 'United States', 'cores': '560,640', 'rmax': '17,590.0', 'rpeak': '27,112.5', 'power': '8,209'}, {'rank': '3', 'name': 'Sequoia', 'year': 2014, 'description': 'DOE/NNSA/LLNL BlueGene/Q, Power BQC 16C 1.60 GHz, Custom', 'company': 'IBM', 'country': 'United States', 'cores': '1,572,864', 'rmax': '17,173.2', 'rpeak': '20,132.7', 'power': '7,890'}, {'rank': '4', 'name': 'K', 'year': 2014, 'description': 'RIKEN Advanced Institute for Computational Science (AICS) SPARC64 VIIIfx 2.0GHz, Tofu interconnect', 'company': 'Fujitsu', 'country': 'Japan', 'cores': '705,024', 'rmax': '10,510.0', 'rpeak': '11,280.4', 'power': '12,660'}, {'rank': '5', 'name': 'Mira', 'year': 2014, 'description': 'DOE/SC/Argonne National Laboratory BlueGene/Q, Power BQC 16C 1.60GHz, Custom', 'company': 'IBM', 'country': 'United States', 'cores': '786,432', 'rmax': '8,586.6', 'rpeak': '10,066.3', 'power': '3,945'}, {'rank': '6', 'name': 'Piz', 'year': 2014, 'description': 'Swiss National Supercomputing Centre (CSCS) - Cray XC30, Xeon E5-2670 8C 2.600GHz, Aries interconnect , NVIDIA K20x', 'company': 'Cray Inc.', 'country': 'Switzerland', 'cores': '115,984', 'rmax': '6,271.0', 'rpeak': '7,788.9', 'power': '1,754'}, {'rank': '7', 'name': 'Stampede', 'year': 2014, 'description': 'Texas Advanced Computing Center/Univ. of Texas PowerEdge C8220, Xeon E5-2680 8C 2.700GHz, Infiniband FDR, Intel Xeon Phi SE10P', 'company': 'Dell EMC', 'country': 'United States', 'cores': '462,462', 'rmax': '5,168.1', 'rpeak': '8,520.1', 'power': '4,510'}, {'rank': '8', 'name': 'JUQUEEN', 'year': 2014, 'description': 'Forschungszentrum Juelich (FZJ) BlueGene/Q, Power BQC 16C 1.600GHz, Custom Interconnect', 'company': 'IBM', 'country': 'Germany', 'cores': '458,752', 'rmax': '5,008.9', 'rpeak': '5,872.0', 'power': '2,301'}, {'rank': '9', 'name': 'Vulcan', 'year': 2014, 'description': 'DOE/NNSA/LLNL BlueGene/Q, Power BQC 16C 1.600GHz, Custom Interconnect', 'company': 'IBM', 'country': 'United States', 'cores': '393,216', 'rmax': '4,293.3', 'rpeak': '5,033.2', 'power': '1,972'}, {'rank': '10', 'name': 'Cray', 'year': 2014, 'description': 'Government Intel Xeon E5-2660v2 10C 2.2GHz, Infiniband FDR, Nvidia K40', 'company': 'Cray Inc.', 'country': 'United States', 'cores': '72,800', 'rmax': '3,577.0', 'rpeak': '6,131.8', 'power': '1,499'}, {'rank': '11', 'name': 'Pleiades', 'year': 2014, 'description': 'NASA/Ames Research Center/NAS SGI ICE X, Intel Xeon E5-2670/E5-2680v2/E5-2680v3 2.6/2.8/2.5 GHz, Infiniband FDR', 'company': 'HPE', 'country': 'United States', 'cores': '160,768', 'rmax': '3,375.6', 'rpeak': '3,987.9', 'power': '3,141'}, {'rank': '12', 'name': 'HPC2', 'year': 2014, 'description': 'Eni S.p.A. iDataPlex DX360M4, Intel Xeon E5-2680v2 10C 2.8GHz, Infiniband FDR, NVIDIA K20x', 'company': 'IBM', 'country': 'Italy', 'cores': '72,000', 'rmax': '3,188.0', 'rpeak': '4,605.0', 'power': '1,227'}, {'rank': '13', 'name': 'Cray', 'year': 2014, 'description': 'Government Intel Xeon E5-2697v2 12C 2.7GHz, Aries interconnect', 'company': 'Cray Inc.', 'country': 'United States', 'cores': '225,984', 'rmax': '3,143.5', 'rpeak': '4,881.3', 'power': '6,328'}, {'rank': '14', 'name': 'SuperMUC', 'year': 2014, 'description': 'Leibniz Rechenzentrum iDataPlex DX360M4, Xeon E5-2680 8C 2.70GHz, Infiniband FDR', 'company': 'IBM/Lenovo', 'country': 'Germany', 'cores': '147,456', 'rmax': '2,897.0', 'rpeak': '3,185.1', 'power': '3,423'}, {'rank': '15', 'name': 'TSUBAME', 'year': 2014, 'descrip ...

# %% [markdown]
# Your output before store in Sql should be something like:
#
# [{'ranking': 1,
#   'name': 'Tianhe-2A',
#   'year': 2014,
#   'description': 'National Super Computer Center in Guangzhou Cluster  Intel Xeon E5-2692 12C 2.200GHz  TH Express-2',
#   'company': 'NUDT',
#   'country': 'China',
#   'cores': 3120000,
#   'rmax': 33862.7,
#   'rpeak': 54902.4,
#   'power': 17808},
#
#  {'ranking': 2,
#   'name': 'Titan',
#   'year': 2014,
#   'description': 'DOE/SC/Oak Ridge National Laboratory XK7  Opteron 6274 16C 2.200GHz  Cray Gemini interconnect',
#   'company': 'Cray Inc.',
#   'country': 'United States',
#   'cores': 560640,
#   'rmax': 17590.0,
#   'rpeak': 27112.5,
#   'power': 8209}....]

# %% [markdown]
# # 1-B
#
#
# When you complete this task, you need to save the information in a SQL database. For that:
# 1. Install MySQL and MySQL connector for Python.
# 2. Start MySQL server on your computer.
# 3. Create a new empty database.
# 4. Create a table for store the data. As an example, the table could be:
#  ```sql
#    CREATE TABLE top_500(
#            ranking int,
#            name text,
#            year int,
#            description text,
#            company text,
#            country text,
#            cores int,
#            rmax float,
#            rpeak float,
#            power int);
# ```

# %%
# Your code here

import MySQLdb

db = MySQLdb.connect(host="localhost",    # your host, usually localhost
                     user="root",         # your username
                     passwd="megajonhy",  # your password
                     db="jonhydb")
